# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
import random
import pickle
import re

# %%
data = [["I want to know more about storm in bangalore",12],["please tell me something about kasauli rhythm that is in kasauli",12],["give detailed information about shiva squad festival in manali",12],["mood indigo, mumbai",12],["more informaiton on woods talk, rishikesh",12],
        ["I want to know more about champaner pavagadh archaeological park, gujarat",11],["please tell me something about pink city that is in jaipur",11],["give detailed information about churches and convents in goa",11],["golden temple amritsar",11],["more informaiton on mecca-masjid hyderabad",11],
        ["I want to know more about qutub minar and red fort in delhi",10],["please tell me something about taj mahal in agra",10],["give detailed information about ajanta and ellora caves in maharashtra",10],["sun temple konark odisha",10],["more informaiton on hill forts rajasthan",10],
        ["I want to know more about zanskar valley ladakh",9],["please tell me something about sand sunes jaisalmer",9],["give detailed information about brackish lagoons in alleppey",9],["coral reef lakshadweep",9],["more informaiton on shola forest nilgiri",9],
        ["no",8],["nop",8],["nope",8],["nah",8],["nada",8],["hell no",8],["not at all",8],["negative",8],["na",8],
        ["thanks",7],["thank you",7],["wow",7],["nice",7],["amazing",7],["great stuff",7],['yayyy',7],
        ["yea",6],["yes",6],["yup",6],["sure",6],["alright",6],["cool",6],["hell yea",6],["why not",6],["ya",6],["of course",6],["okay",6],["ok",6],["cool",6],
        ["bye",5],["bye bye",5],["good night",5],["good bye",5],["tata",5],["see you later",5],["see ya",5],["have a nice day",5],["later",5],
        ["events",4],["concert",4],["live",4],["dj",4],["expo",4],["sessions",4],["conferences",4],["party",4],["parties",4],["festivals",4],["awards",4],["competition",4],["presentation",4],["speaker",4],["audience",4],["meetup",4],["meeting",4],["meet up",4],["social event",4],["social",4],["organizers",4],["drama",4],["play",4],["act",4],["stage",4],["poetry reading",4],["performance",4],["dance",4],["paint",4],["draw",4],["art",4],["rap",4],["sing",4],["cooking",4],["cook",4],["makeup",4],["magic show",4],["exhibition",4],
        ["man made",3],["galleries",3],["statues",3],["leisure",3],["shopping",3],["theatre",3],["sporting venue",3],["movies",3],["park",3],["gardens",3],["fountain",3],["skyline",3],["farms",3],["paintings",3],["malls",3],["hotels",3],["restaurants",3],["resorts",3],["gaming",3],["amusement parks",3],["roller coster",3],["electronics",3],["accessories",3],["jewellery",3],["gadgets",3],
        ["ancient",2],["historic",2],["forts",2],["cultura;",2],["longtime",2],["historical significance",2],["ruins",2],["monuments",2],["shrines",2],["castles",2],["battle fields",2],["railways",2],["temple",2],["ghats",2],["caves",2],["old",2],["military sites",2],["culture",2],["preservation",2],["traditional",2],["origins",2],["ancestry",2],["asset",2],["possession",2],["heir",2],["heredity",2],["ancestral",2],["preserve",2],["treasure",2],["landmark",2],["historically",2],["succession",2],["heritage",2],
        ["natural",1],["earth",1],["nature",1],["life",1],["habitat",1],["biology",1],["geography",1],["water",1],["ocean",1],["ecology",1],["ecosystem",1],["air",1],["ice",1],["snow",1],["snowfall",1],["snowflakes",1],["organism",1],["desert",1],["environment",1],["sea",1],["ocean",1],["wild",1],["wildness",1],["naturalism",1],["climate",1],["lake",1],["spring",1],["glacier",1],["biodiversity",1],["flora",1],["fauna",1],["flower",1],["birds",1],["landscape",1],["rock",1],["natural",1],["biological",1],["animals",1],
        ["hi",0],["good morning",0],["hello",0],["heya",0],["ssup",0],["good afternoon",0],["hey",0],["yo",0]]

# %%
df = pd.DataFrame(data, columns = ['text', 'intent'])

# %%
x = df['text']
y = df['intent']

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(x)

# %%
clf  = LinearSVC(max_iter=800, C=0.75)

# %%
clf.fit(X,y)
# Out:
# LinearSVC(C=0.75, max_iter=800)

# %%
pickle.dump(clf,open("model.pkl", 'wb'))

# %%
load_model = pickle.load(open("model.pkl", 'rb'))

# %%
responses ={0 : {"intent":"greetings","response":['Hello! Please tell me what you like to be around/like to do when you plan on visiting any place in India and I can tell you which category is the most suitable for you.','Hey bro! Please tell me what you like to be around/like to do when you plan on visiting any place in India and I can tell you which category is the most suitable for you.','Planning to go on a trip haan? Please tell me what you like to be around/like to do when you plan on visiting any place in India and I can tell you which category is the most suitable for you.']}, 
            1 : {"intent":"nature","response":['Great! You should definitely go to a place where you can connect with nature','Wow so how about you go to places where you can connect with nature?']},
            2 : {"intent":"heritage","response":['I like your choice! You can go to places with heritage attractions','Hey how about you go somewhere with heritage attractions?']},
            3 : {"intent":"manmade","response":['How about you to some place that has many purposeful built (man-made) attractions?','Good choice! I think you should go somewhere with alot of manmade attractions!']},
            4 : {"intent":"event","response":['What an amazing choice! You should definitely go to a place where people host alot of events!']},
            5 : {"intent":"farewell","response":['See ya! Take care.','Bye bye! Have a nice day.','Click a lot of pictures when you go on a vacation!','See ya. I hope you start planning for your vacation soon!']},
            7 : {"intent":"praise","response":['Yesss I am amazing!','Pleasure helping you out!','I hope I was of some help...']},
            8 : {"intent":"negative","response":['Oh alright.','Okay no problem mate','So you already have planned everything :)']}}

# %%
type = []
def response(user_response):
    flag = True
    while(flag==True):
        user_response = user_response.lower()
        user_response = re.sub(r"[!'#$%&()*+,-./:;<=>?@[\]^_`{|}~]",'',user_response)
        text_test = [user_response]
        X_test = vectorizer.transform(text_test)
        prediction = clf.predict(X_test)
        
        if user_response == 'start':
            reply = """Hello! I am a travel suggestor bot.
Please tell me what you like to be around/like to do when you plan on visiting any place in India and I can tell you which category is the most suitable for you."""
        
        elif prediction == 0: #greeting
            reply = random.choice(responses[0]['response'])
        
        elif prediction == 1: #nature
            type.append(1)
            reply = random.choice(responses[1]['response']) + "\nCan I suggest you any places in India according to your interest?"
        
        elif prediction == 2: #heritage
            type.append(2)
            reply = random.choice(responses[2]['response']) + "\nCan I suggest you any places in India according to your interest?"
        
        elif prediction == 3: #manmade
            type.append(3)
            reply = random.choice(responses[3]['response']) + "\nCan I suggest you any places in India according to your interest?"
        
        elif prediction == 4: #events
            type.append(4)
            reply = random.choice(responses[4]['response']) + "\nCan I suggest you any places in India according to your interest?"
        
        elif prediction == 5: #farewell
            reply = random.choice(responses[5]['response'])
    
        elif prediction == 6: #positive
            if len(type) == 0:
                reply = "I am waiting..."
            elif len(type)>0:
                if type[-1]>0 and type[-1]<5:
                    reply = "Great okayy! Let me get my binder!!\n\nOkay sooo this is what I have for you!!"
                if type[-1] == 1:
                    reply = reply + """ The places you can go visit are: 
            
            1) Zanskar Valley -Ladakh
            2) Sand Dunes -Jaisalmer
            3) Brackish Lagoons -Alleppey
            4) Coral Reef -Lakshadweep
            5) Shola Forest -Nilgiri"""
                elif type[-1] == 2:
                    reply = reply + """ The places you can go visit are:
            
            1) Qutub Minar and Red Fort, Delhi
            2) Taj Mahal, Agra
            3) Ajanta and Ellora Caves, Maharashtra
            4) Sun Temple, Konark, Odisha
            5) Hill Forts of Rajasthan"""
                elif type[-1] == 3:
                    reply = reply + """ The places you can go visit are:
            
            1) Champaner-Pavagadh Archaeological Park, Gujarat
            2) The Pink City - Jaipur
            3) Churches and Convents of Goa
            4) The Golden Temple, Amritsar
            5) Mecca Masjid - Hyderabad"""
                elif type[-1] == 4:
                    reply = reply + """ The places you can go visit are:
            
            1) Storm, Bangalore
            2) Kasauli Rhythm, Kasauli
            3) Shiva Squad Festival, Manali
            4) Woods Talk, Rishikesh
            5) Mood Indigo, Mumbai"""
        elif prediction == 7: #praise
            reply = random.choice(responses[7]['response'])
        elif prediction == 8: #negative
            reply = random.choice(responses[8]['response'])
        elif prediction == 9: #nature places
            reply = """You might have asked for just one place but I will give you information about all the places!

➤Zanskar Valley, Ladakh
    Zanskar is one of the known Buddhist kingdoms of the western Himalayas within elevation of 12000 feet.
➤Sand Dunes, Jaisalmer
    City Jaisalmer is located in the midst of Thar desert and is close to number of Sand dunes. One of the famous tourist attraction is the Sam sand dunes.
➤Brackish Lagoons, Alleppey
    The Kerala backwaters are a chain of brackish lagoons and lakes lying parallel to the Arabian Sea coast (known as the Malabar Coast) of Kerala state in southern India.
➤Coral Reef, Lakshadweep
    Lakshadweep comprises twelve atolls, three reefs and five submerged banks, with a total of about thirty-six islands and islets.
➤Shola Forest, Nilgiri
    These forests are found sheltered in valleys with sufficient moisture and proper drainage, at an altitude of more than 1,500 metres."""
        elif prediction == 10: #heritage places
            reply = """You might have asked for just one place but I will give you information about all the places!

➤Qutub Minar and Red Fort, Delhi
    Qutab Minar is a minaret and "victory tower" that forms part of the Qutb complex. The Red Fort is a historic fort in the city of Delhi in India that served as the main residence of the Mughal Emperors.
➤Taj Mahal, Agra
    The Taj Mahal is an ivory-white marble mausoleum on the southern bank of the river Yamuna in the Indian city of Agra.
➤Ajanta and Ellora Caves, Maharashtra
    Ajanta is 100 kilometres (62 miles) from the Ellora Caves, which contain Hindu, Jain and Buddhist caves.
➤Sun Temple, Konark, Odisha
    The Konark Sun temple is dedicated to the Hindu sun god Surya, and, conceived as a giant stone chariot with 12 wheels.
➤Hill Forts of Rajasthan
    The hill forts of Rajasthan is a serial site, comprises six majestic forts in Chittorgarh; Kumbhalgarh; Sawai Madhopur; Jhalawar; Jaipur, and Jaisalmer."""
        elif prediction == 11: #manmade places
            reply = """You might have asked for just one place but I will give you information about all the places!

➤Champaner-Pavagadh Archaeological Park, Gujarat
    Champaner-Pavagadh Archaeological Park, a UNESCO World Heritage Site, is located in Panchmahal district in Gujarat, India.
➤The Pink City, Jaipur
    Jaipur is also known as the Pink City, due to the dominant color scheme of its buildings. It was constructed within a period of four years.
➤Churches and Convents of Goa
    The Churches and Convents of Goa are a group of Catholic religious buildings that have been influential for spreading both the faith and their Portuguese style of art and architecture around Asia.
➤The Golden Temple, Amritsar
    The Golden Temple Amritsar India is not only a central religious place of the Sikhs, but also a symbol of human brotherhood and equality.
➤Mecca Masjid, Hyderabad
    One of the oldest mosques in the city, the Mecca Masjid in Hyderabad is one of the largest Masjids in India."""
        elif prediction == 12: #events places
            reply = """You might have asked for just one place but I will give you information about all the places!

➤Storm, Bangalore
    Summer Storm Festival is an annual music festival which takes place in Bangalore, India at the Palace Grounds.
➤Kasauli Rhythm, Kasauli
    The Kausali Rhythm and Blues Festival brings together epic indie artists from across the country for two whole days of good music in the hills.
➤Shiva Squad Festival, Manali
    Shiva Squad Festival is a three-day-long event of adventure, music, healing, culture; held on hillocks of the Himalaya in Manali, Himachal Pradesh from 25 to 27 September every year.
➤Woods Talk, Rishikesh
    A chill open-air festival in the lush hills of Rishikesh, Woods Talk is held in the month of March annually. This festival also offers adventure activities like rafting, kayaking rappelling, canyoning and rock climbing around the rich landscape of the area.
➤Mood Indigo, Mumbai
    Mood Indigo, Asia's largest college cultural festival, has developed over the years into so much more: a melting pot of Indian and global culture, a launchpad for upcoming artists, a spectacular showcase of talent, an epitome of incredible human experience."""
        return reply

# %%
import requests
import json

class telegram_bot():
    def __init__(self):
        self.token = "#######################################"    #write your token here!
        self.url = f"https://api.telegram.org/bot{self.token}"

    def get_updates(self,offset=None):
        url = self.url+"/getUpdates?timeout=1000"
        if offset:
            url = url+f"&offset={offset+1}"
        url_info = requests.get(url)
        return json.loads(url_info.content)

    def send_message(self,msg,chat_id):
        url = self.url + f"/sendMessage?chat_id={chat_id}&text={msg}"
        if msg is not None:
            requests.get(url)

    def grab_token(self):
        return tokens

# %%
tbot = telegram_bot()

update_id = None

def make_reply(user_response):
    reply = ""
    if user_response is not None:
        reply = response(user_response)
    return reply

while True:
    print("...")
    updates = tbot.get_updates(offset=update_id)
    updates = updates['result']
    print(updates)
    if updates:
        for item in updates:
            update_id = item["update_id"]
            print(update_id)
            try:
                message = item["message"]["text"]
                print(message)
            except:
                message = None
            from_ = item["message"]["from"]["id"]
            print(from_)

            reply = make_reply(message)
            tbot.send_message(reply,from_)
# Out:
# ...
# [{'update_id': 144849960, 'message': {'message_id': 299, 'from': {'id': 976521729, 'is_bot': False, 'first_name': 'Arpit', 'last_name': 'Chauhan', 'username': 'arpit09chauhan'}, 'chat': {'id': 976521729, 'first_name': 'Arpit', 'last_name': 'Chauhan', 'username': 'arpit09chauhan', 'type': 'private'}, 'date': 1592573843, 'text': '/start', 'entities': [{'offset': 0, 'length': 6, 'type': 'bot_command'}]}}]
# 144849960
# /start
# 976521729
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# []
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ...
